# %% [markdown]
# ### 🧭 Create a Quiver Plot of a 2D Gaussian Field Using Python 🌪️

# %%
import numpy as np  # 🔢 Numerical operations
import matplotlib.pyplot as plt  # 📊 Plotting library

# 🌐 Define a 2D Gaussian-like function
f = lambda x, y, x0, y0, sig: np.exp((-(x - x0)**2 - (y - y0)**2) / sig**2)

# 🧱 Create a meshgrid
X, Y = np.meshgrid(np.arange(50), np.arange(50))

# 📈 Apply the function to generate a 2D array
array = f(X, Y, 24, 24, 7.)

# 🔄 Compute the gradient (directional changes)
dy, dx = np.gradient(array)

n = 3  # 🎯 Step for downsampling the grid for quiver

plt.figure(figsize=(7, 7))  # 🖼️ Set the figure size
plt.imshow(array)  # 🌈 Show the heatmap

# 🧭 Plot quiver vectors (arrows showing gradient direction & strength)
plt.quiver(
    X[::n, ::n], Y[::n, ::n],         # 🧭 Grid positions
    dx[::n, ::n], -dy[::n, ::n],      # ➡️ Gradient direction (invert y-axis)
    np.sqrt(dx[::n, ::n]**2 + dy[::n, ::n]**2),  # 📏 Magnitude of gradient
    units="xy", scale=0.04, cmap="Reds"  # 🎨 Arrow styling
)

plt.title("🧭 Quiver Plot of a 2D Gaussian Field")  # 🏷️ Add a title
plt.show()  # 👁️ Display the plot
# Out:
# C:\Users\nazish\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129517 (\N{COMPASS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
