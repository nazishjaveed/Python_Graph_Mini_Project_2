# %% [markdown]
# ### 🟩📊 Create Square Scatter Plot Using Python 🐍🎨

# %%
import matplotlib.pyplot as plt
import numpy as np

# 🌱📊 Generate random data
np.random.seed(0)
x = np.random.rand(60) * 50
y = np.random.rand(60) * 50
colors = np.random.rand(60) * 50  # 🎨 Color scale
sizes = np.random.rand(60) * 1000  # 🔲 Size scale for squares

# 🖼️ Create the plot
plt.figure(figsize=(8, 6))
scatter = plt.scatter(x, y, s=sizes, c=colors, cmap='summer', marker='s', alpha=0.8)

# 🌡️ Add colorbar
plt.colorbar(scatter)

# 🏷️ Add title
plt.title("🟩 Square Scatter Plot Example")

# 👀 Show plot
plt.show()
