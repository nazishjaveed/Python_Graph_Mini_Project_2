# %% [markdown]
# ### Create sinusoidal plots using Python 🐍📈

# %%
import matplotlib.pyplot as plt
import numpy as np

# 📊 Generate X values
x = np.linspace(0, 10, 25)

# 🌊 Generate Y values
y1 = np.sin(x)  # 🔵 Sine wave
y2 = np.cos(x)  # 🔴 Cosine wave

# 🎨 Create the plot
plt.plot(x, y1, 'bo-', label='Line 1 (sin) 🔵')   # blue circle markers with solid line
plt.plot(x, y2, 'r*:', label='Line 2 (cos) 🔴')   # red star markers with dotted line

# 🏷️ Add labels and title
plt.xlabel('X-axis ➡️')
plt.ylabel('Y-axis ⬆️')
plt.title('Sinusoidal Waves 🌊📈')

# 📌 Add legend
plt.legend()

# 📐 Show grid and plot
plt.grid(True)
plt.show()
