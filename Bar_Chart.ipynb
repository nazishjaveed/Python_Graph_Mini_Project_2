# %% [markdown]
# ### 🎨📊 Create Bar Chart Using Python 🐍✨

# %%
import matplotlib.pyplot as plt  # 📊 For plotting
import numpy as np  # 🔢 Numerical operations

# 📅 Sample data for UK election results (fictional or illustrative)
years = [1950, 1951, 1955, 1959, 1964, 1966, 1970, 1974, 1974.5, 1979, 1983, 1987, 1992, 1997, 2001, 2005, 2010, 2015, 2017, 2019]
conservative = [300, 320, 345, 360, 290, 270, 330, 300, 270, 340, 360, 375, 340, 170, 165, 200, 305, 330, 315, 360]  # 🔵
labour =       [295, 300, 280, 260, 320, 340, 280, 310, 330, 270, 210, 200, 270, 420, 410, 350, 260, 230, 260, 200]  # 🔴
liberal =      [10, 15, 20, 30, 25, 15, 20, 35, 40, 20, 25, 30, 25, 50, 55, 60, 50, 60, 40, 35]  # 💛
others =       [5, 10, 15, 10, 5, 5, 10, 15, 10, 10, 5, 5, 5, 10, 20, 25, 35, 40, 45, 50]  # ⚫

# 📏 Set bar width
bar_width = 0.2
x = np.arange(len(years))

# 📊 Plotting the bar chart for each party
plt.bar(x - 1.5*bar_width, conservative, width=bar_width, label='Conservative 🔵', color='blue')
plt.bar(x - 0.5*bar_width, labour, width=bar_width, label='Labour 🔴', color='red')
plt.bar(x + 0.5*bar_width, liberal, width=bar_width, label='Liberal 💛', color='yellow')
plt.bar(x + 1.5*bar_width, others, width=bar_width, label='Others ⚫', color='grey')

# 🧾 Customize the plot
plt.xlabel('Year 📆')
plt.ylabel('Seats 🎯')
plt.title('UK Election Results 🇬🇧🗳️')
plt.xticks(ticks=x, labels=years, rotation=45)
plt.legend()

# 📷 Show the plot
plt.tight_layout()
plt.show()
