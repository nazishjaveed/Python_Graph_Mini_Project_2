# %% [markdown]
# ### 🌈 Create Rainbow Graph Using Python 🐍📈

# %%
import matplotlib.pyplot as plt  # 📊
import numpy as np  # 🔢

x = np.linspace(0, 100, 50)  # ➰ Generate 50 points between 0 and 100

y_old = -(x - 50) ** 2 + 2500  # 🟢 Initial parabola
for delta, color in zip([2250, 2000, 1750, 1500, 1250, 1000], ["r", "orange", "g", "b", "indigo", "violet"]):
    y_new = -(x - 50) ** 2 + delta  # ➕ Shift parabola upward
    plt.plot(x, y_old, "-k")  # ⚫ Draw outline of each band
    plt.fill_between(x, y_old, y_new, color=color)  # 🌈 Fill between parabolas with color
    y_old = y_new  # 🔁 Update for next band

plt.ylim(0, 2500)  # 📏 Set y-axis limit
plt.show()  # 👀 Display plot
