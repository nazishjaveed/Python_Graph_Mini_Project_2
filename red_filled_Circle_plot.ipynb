# %% [markdown]
# ### Create Shifted Parabola Plot Using Python 🐍📉🔴

# %%
import matplotlib.pyplot as plt
import numpy as np

# 🔢 Generate x values
x = np.linspace(-1, 1, 30)

# 📉 Generate y values (Shifted parabola)
y = x**2 - 1  # ⬇️ This shifts the parabola down

# 🎯 Create the plot
plt.plot(x, y, 'ro', markersize=10, markeredgecolor='k')  # 🔴 Red circles with black edges

# 🏷️ Add title
plt.title('Shifted Parabola Plot (y = x² - 1) 🔴📉')

# 📐 Show grid and plot
plt.grid(True)
plt.show()
